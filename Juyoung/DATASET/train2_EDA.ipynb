# %%
import pandas as pd
import numpy as np
from sklearn.utils import class_weight

# %%
train2_df=pd.read_csv('/root/CV_PJT/CV_PJT/code/train2.csv')

# %%
len(df)
# Out:
# 147984

# %%
# Set the figure size
plt.figure(figsize=(8, 6))

# Count the number of predictions per class
sns.countplot(x='target', data=df, palette='Set2')
plt.title('Distribution of Predicted Classes')
plt.xlabel('Class Labels')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_158348/449482556.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='target', data=df, palette='Set2')

# %%
train_labels = train2_df['target'].values  # Convert to a NumPy array

# Calculate class weights
classes = np.unique(train_labels)
weights = class_weight.compute_class_weight('balanced', classes=classes, y=train_labels)

# Create a dictionary for class weights
class_weights = {i: weights[i] for i in range(len(weights))}
print(class_weights)
# Out:
# {0: 0.9891978609625669, 1: 1.0752150662636597, 2: 0.9891978609625669, 3: 0.9891978609625669, 4: 0.9891978609625669, 5: 0.9891978609625669, 6: 0.9891978609625669, 7: 0.9891978609625669, 8: 0.9891978609625669, 9: 0.9891978609625669, 10: 0.9891978609625669, 11: 0.9891978609625669, 12: 0.9891978609625669, 13: 1.0503066091301385, 14: 1.0363025210084034, 15: 0.9891978609625669, 16: 0.9891978609625669}
